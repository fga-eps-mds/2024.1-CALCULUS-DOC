# %% [markdown]
# ### LIBRARIES

# %% [markdown]
# # Analytics - Product Quality
#
# #### Date: 2024/01
#
# #### SUMMARY:
#
# - This notebook represents the project quality analysis of the date exposed right above.
#
# ### TEAM:
#
# ##### Semester: 2024/01
# ##### Professor: Hilmer Neri
#
# ##### Members:
#
# EPS:
#
# - Davi Matheus da Rocha de Oliveira
# - Natanael Fernandes Coelho Filho
# - João Victor Max Bisinotti de Oliveira
# - Paulo Henrique Costa Gontijo
#
# MDS:
#
# - Pedro Fonseca Cruz
# - Marco Marques de Castro
# - Natan da Cruz Almeida
# - Paulo Henrique Lamounier Dantas
# - Kauã Seichi Gomes de Souza
# - Jonas Carlos do Nascimento
# - João Vitor Lopes Ribeiro

# %%
# Deal with data
import pandas as pd
import json
from glob import glob

# Deal with visualization
import matplotlib.pyplot as plt

# Deal with time
import datetime
import requests

import os
import git # Import the gitpython library

# Clone a repository
repo_url = 'https://github.com/fga-eps-mds/2024.1-CALCULUS-DOC'  # Replace with your repository URL
clone_dir = './kaggle/working/CALCULUS'  # Directory to clone the repository into

if not os.path.exists(clone_dir):
    print(f"Cloning repository from {repo_url} into {clone_dir}...")
    git.Repo.clone_from(repo_url, clone_dir)
    print("Repository cloned successfully.")
else:
    print(f"Directory {clone_dir} already exists. Skipping clone.")

# Set the cloned directory as the working directory
os.chdir(clone_dir)
print(f"Current working directory: {os.getcwd()}")

# List all files in the cloned directory
for dirname, _, filenames in os.walk('.'):  # '.' now points to clone_dir
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Cloning repository from https://github.com/fga-eps-mds/2024.1-CALCULUS-DOC into ./kaggle/working/CALCULUS...
# Repository cloned successfully.
# Current working directory: /home/ntl/workspace/facu/eps/2024.1-CALCULUS-DOC/Analytics/kaggle/working/CALCULUS/kaggle/working/CALCULUS
# ./.gitignore
# ./LICENSE
# ./README.md
# ./mkdocs.yml
# ./requirements.txt
# ./.git/description
# ./.git/packed-refs
# ./.git/HEAD
# ./.git/config
# ./.git/index
# ./.git/hooks/applypatch-msg.sample
# ./.git/hooks/commit-msg.sample
# ./.git/hooks/post-update.sample
# ./.git/hooks/pre-applypatch.sample
# ./.git/hooks/pre-commit.sample
# ./.git/hooks/pre-merge-commit.sample
# ./.git/hooks/pre-push.sample
# ./.git/hooks/pre-receive.sample
# ./.git/hooks/push-to-checkout.sample
# ./.git/hooks/sendemail-validate.sample
# ./.git/hooks/update.sample
# ./.git/hooks/fsmonitor-watchman.sample
# ./.git/hooks/pre-rebase.sample
# ./.git/hooks/prepare-commit-msg.sample
# ./.git/info/exclude
# ./.git/objects/pack/pack-a891eb86c1be424b05637f9322c33bedd0c6d8d5.pack
# ./.git/objects/pack/pack-a891eb86c1be424b05637f9322c33bedd0c6d8d5.rev
# ./.git/objects/pack/pack-a891eb86c1be424b05637f9322c33bedd0c6d8d5.idx
# ./.git/refs/heads/main
# ./.git/refs/remotes/origin/HEAD
# ./.git/logs/HEAD
# ./.git/logs/refs/remotes/origin/HEAD
# ./.git/logs/refs/heads/main
# ./.github/pull_request_template.md
# ./.github/ISSUE_TEMPLATE/template-das-issues.md
# ./.github/ISSUE_TEMPLATE/template-de-bug-report.md
# ./.github/ISSUE_TEMPLATE/template_user_story.md
# ./.github/workflows/ci.yml
# ./Analytics/README.md
# ./Analytics/analytics.ipynb
# ./Analytics/data/2024.1-CALCULUS--08-26-2024--20-13-52.csv
# ./Analytics/data/2024.1-CALCULUS--08-26-2024--20-13-52.xlsx
# ./Analytics/data/2024.1-CALCULUS--08-26-2024--20-14-23.csv
# ./Analytics/data/2024.1-CALCULUS--08-26-2024--20-14-23.xlsx
# ./Analytics/data/2024.1-CALCULUS--08-26-2024--20-14-55.csv
# ./Analytics/data/2024.1-CALCULUS--08-26-2024--20-14-55.xlsx
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-Frontend-08-01-2024-01-38-15-0.0.9.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-Frontend-08-02-2024-19-11-04-0.0.10.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-Frontend-08-05-2024-22-32-03-0.0.11.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-Frontend-08-13-2024-18-11-39-0.0.12.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-Frontend-08-19-2024-23-34-11-0.0.13.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-Frontend-08-20-2024-15-16-18-0.0.14.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-Frontend-08-20-2024-15-46-59-0.0.15.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-Frontend-08-21-2024-13-25-41-0.0.16.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-Frontend-08-21-2024-15-37-22-0.0.17.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-Frontend-08-22-2024-18-24-36-0.0.18.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-Frontend-08-25-2024-20-28-48-0.0.19.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-Frontend-08-25-2024-21-42-55-0.0.20.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-Frontend-08-26-2024-15-49-24-0.0.21.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-Frontend-08-26-2024-18-10-25-0.0.22.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-StudioMaker-08-18-2024-23-52-10-0.0.2.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-StudioMaker-08-19-2024-00-50-49-0.0.3.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-StudioMaker-08-19-2024-02-15-22-0.0.4.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-StudioMaker-08-27-2024-14-39-40-0.0.5.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-07-10-2024-22-24-24-0.0.1.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-07-28-2024-22-05-28-0.0.2.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-07-28-2024-22-05-29-0.0.3.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-07-30-2024-23-15-08-0.0.4.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-07-31-2024-01-55-48-0.0.5.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-07-31-2024-03-43-18-0.0.6.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-07-31-2024-17-35-37-0.0.7.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-08-03-2024-21-58-22-0.0.8.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-08-04-2024-21-26-41-0.0.9.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-08-13-2024-18-13-39-0.0.10.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-08-18-2024-20-45-44-0.0.11.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-08-18-2024-21-00-13-0.0.12.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-08-18-2024-21-49-25-0.0.13.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-08-18-2024-22-40-00-0.0.14.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-08-18-2024-23-50-00-0.0.15.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-08-25-2024-22-50-05-0.0.16.json
# ./analytics-raw-data/fga-eps-mds-2024.1-CALCULUS-UserService-08-27-2024-14-55-09-0.0.17.json
# ./docs/index.md
# ./docs/assets/Primary-Color-Theme.jpeg
# ./docs/assets/Secundary-Color-Theme.jpeg
# ./docs/assets/calculus-logo1.png
# ./docs/assets/calculus-logo2.png
# ./docs/assets/eap.png
# ./docs/assets/logo.svg
# ./docs/assets/paleta.jpeg
# ./docs/assets/tipografia.png
# ./docs/assets/gitflow/diagrama-gitflow.drawio.png
# ./docs/assets/lean/brainstorm.png
# ./docs/assets/lean/canvas_mvp.png
# ./docs/assets/lean/faz_naofaz.png
# ./docs/assets/lean/objeitvos_produto.png
# ./docs/assets/lean/revisao_tecnica.png
# ./docs/assets/lean/sequenciador.png
# ./docs/assets/lean/visao_produto.png
# ./docs/assets/lean/jornadas/jornada_1.png
# ./docs/assets/lean/jornadas/jornada_2.png
# ./docs/assets/lean/jornadas/jornada_3.png
# ./docs/assets/lean/jornadas/jornada_4.png
# ./docs/assets/lean/personas/persona_1.png
# ./docs/assets/lean/personas/persona_2.png
# ./docs/assets/lean/personas/persona_3.png
# ./docs/assets/lean/personas/persona_4.png
# ./docs/atas/reuniao1.md
# ./docs/atas/reuniao2.md
# ./docs/atas/reuniao3.md
# ./docs/dojo/dojo-docker.md
# ./docs/dojo/dojo-frontend.md
# ./docs/dojo/dojo-git.md
# ./docs/dojo/dojo-markdown.md
# ./docs/guias/codigo-conduta.md
# ./docs/guias/guia-contribuicao.md
# ./docs/guias/guia-estilo.md
# ./docs/lean/brainstorms_funcionalidades.md
# ./docs/lean/canvas_mvp.md
# ./docs/lean/faz_nao_faz.md
# ./docs/lean/jornada_usuário.md
# ./docs/lean/objetivos_produto.md
# ./docs/lean/personas.md
# ./docs/lean/revisao_tecnica.md
# ./docs/lean/sequenciador.md
# ./docs/lean/visao_produto.md
# ./docs/organizacoes/EVM.md
# ./docs/organizacoes/documento_arquitetura.md
# ./docs/organizacoes/eap.md
# ./docs/organizacoes/tap.md
# ./docs/planejamento/agenda_ritual.md
# ./docs/planejamento/comunicacao.md
# ./docs/planejamento/conhecimento_pareamento.md
# ./docs/planejamento/quadro_de_disponibilidade.md
# ./docs/planos/plano_qualidade.md
# ./docs/planos/planos_custos.md
# ./docs/planos/planos_riscos.md
# ./docs/stylesheets/extra.css

# %%
owner = 'fga-eps-mds'
repos = ['2024.1-CALCULUS-Frontend', '2024.1-CALCULUS-UserService', '2024.1-CALCULUS-StudioMaker']

data = []

for repo in repos:
    url = f'https://api.github.com/repos/{owner}/{repo}/actions/runs'
    
    response = requests.get(url)
    
    if response.status_code == 200:
        data_ = response.json()
        data.extend(data_.get('workflow_runs', []))
    else:
        print(f"Erro ao acessar a API do GitHub para o repositório {repo}: {response.status_code}")

# %% [markdown]
# ## Github API
#
# A API do GitHub utiliza principalmente o protocolo HTTP, onde as operações são realizadas através de URLs e métodos HTTP, como GET, POST, PUT e DELETE. Os dados são geralmente retornados em formato JSON, tornando-o fácil de processar e interpretar.

# %%
data = glob('./analytics-raw-data/GitHub_API-fga-eps-mds-*.json')
# print(data)

# %% [markdown]
# #### Unmarshall json

# %%
def unmarshall(json_path: str) -> dict:
    with open(json_path) as json_file:
        json_obj = json.load(json_file)
    return json_obj

# %% [markdown]
# ### Cálculo dos dados
#
# - Carrega dados dos arquivo JSON e armazena-os na variável data.
# - Processa os dados do JSON para calcular e obter informações relevantes sobre os tempos de feedback de cada execução de workflow, separando-os em listas de feedback_times, authors_feedback_times, e ci_feedback_times.
# - Calcula o tempo médio de feedback (ci_feedback_time) considerando todas as execuções de workflow.
# - Calcula o tempo médio de feedback de cada autor e armazena essas informações em authors_avg_feedback_times.
# - Processa novamente os dados do JSON para contar o número de execuções bem-sucedidas (success_count) e falhas (failure_count) dos workflows.

# %%
tabela_total = pd.DataFrame()

# Processar os dados do JSON e obter as informações relevantes
success_count = 0
failure_count = 0

for json_path in data:
    dados = unmarshall(json_path)
    # Create a list to store the data for the table
    table_data = []
    # Processar os dados do JSON e obter as informações relevantes
    for run in dados["workflow_runs"]:
        updated_at = datetime.datetime.strptime(run["updated_at"], "%Y-%m-%dT%H:%M:%SZ")
        created_at = datetime.datetime.strptime(run["created_at"], "%Y-%m-%dT%H:%M:%SZ")
        feedback_time = (updated_at - created_at).total_seconds()
        
        # informações relevantes
        workflow_id = run["id"]
        conclusion = run["conclusion"]
        author = run["actor"]["login"]
        
        # Adiciona os dados na tabela
        table_data.append({
            "Workflow_run ID": workflow_id,
            "Conclusion": conclusion,
            "Author": author,
            "Created at": created_at,
            "Updated at": updated_at,
            "Feedback Time": feedback_time
        })
        
        
    # Cria um dataframe com o pandas
    df = pd.DataFrame(table_data)

    
    # table_data_global.append(df)
    
    # Processar os dados do JSON e obter as informações relevantes
    feedback_times = []
    authors_feedback_times = {}
    ci_feedback_times = []

    for run in df.index:
        updated_at = df["Updated at"][run]
        created_at = df["Created at"][run]
        feedback_time = (updated_at - created_at).total_seconds()
        feedback_times.append(feedback_time)
        
    # Calcular o CI FeedBack Time
    ci_feedback_time = sum(feedback_times) / len(feedback_times)
    df["Ci Feedback Time"] = ci_feedback_time
    
    # Tabela com todas as linhas
    tabela_total = pd.concat([tabela_total, df])
    # print('Tabela por dia')
    # display(df)

    for run in dados["workflow_runs"]:
        conclusion = run["conclusion"]
        if conclusion == "success":
            success_count += 1
        elif conclusion == "failure":
            failure_count += 1
                
print('Tabela com todas as linhas')
display(tabela_total)

# %% [markdown]
# # Gerar gráficos
#
# - Gráfico de linhas: Mostra o "CI FeedBack Time" (tempo de feedback do CI) em relação à "Data de Atualização" das execuções de workflow.
# - Gráfico de barras simples: Exibe o "Tempo Médio de Feedback do CI", representando o desempenho médio geral do CI.
# - Gráfico de pizza: Mostra a "Quantidade de Workflows com Sucesso e Falha" em relação ao total de workflows executados, indicando a proporção de workflows que tiveram sucesso e falha.

# %%
# Gerar gráfico com o CI FeedBack Time por data de atualização

temp = tabela_total[['Created at', 'Ci Feedback Time']]
dates = temp.groupby(['Created at']).mean().reset_index()  # Calcula a média dos valores por data
dates['Created at'] = pd.to_datetime(dates['Created at']) 
print(dates)


# dates = [datetime.datetime.strptime(run["updated_at"], "%Y-%m-%dT%H:%M:%SZ") for run in data["workflow_runs"]]
plt.figure(figsize=(20, 10))
plt.plot(range(len(dates)), dates['Ci Feedback Time'], marker='o', color='b', label='Feedback Time')
plt.xlabel("Created at")
plt.ylabel("CI FeedBack Time")
plt.title("CI FeedBack Time por Data de Criação")
plt.xticks(range(len(dates)), dates['Created at'].dt.strftime('%Y-%m-%d'), rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()  # Ajusta a disposição dos elementos para evitar sobreposições
plt.show()

# %%
plt.figure(figsize=(20, 10))
bars =  plt.bar(range(len(dates)), dates['Ci Feedback Time'], color='salmon', label='Feedback Time')
plt.xlabel("Created at")
plt.ylabel("CI FeedBack Time")
plt.title("CI FeedBack Time por Data de Criação")
plt.xticks(range(len(dates)), dates['Created at'].dt.strftime('%Y-%m-%d'), rotation=45)  # Exibe as datas formatadas no eixo X
plt.legend()
# Adiciona as labels em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, str(height), ha='center', va='bottom')

plt.tight_layout()  # Ajusta a disposição dos elementos para evitar sobreposições
plt.show()

# # Gerar gráfico com o tempo médio do CI
# plt.figure(figsize=(20, 10))
# plt.bar(["CI"], [ci_feedback_time], color='salmon')
# plt.xlabel("CI")
# plt.ylabel("Tempo Médio de Feedback")
# plt.title("Tempo Médio de Feedback do CI")
# plt.text(0, ci_feedback_time, f'{round(ci_feedback_time, 2)} segundos', ha='center', va='bottom', fontweight='bold')
# plt.tight_layout()
# plt.show()

# %%
# Gerar gráfico com a quantidade de workflows com sucesso e falha
labels = ["Success", "Failure"]
sizes = [success_count, failure_count]
plt.figure(figsize=(20, 10))
colors = ['lightgreen', 'crimson']
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors)
plt.title("Quantidade de Workflows_runs com Sucesso e Falha")
plt.legend(labels, loc='best')
plt.tight_layout()
plt.show()
